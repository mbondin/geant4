# %%
# %pylab inline
# %matplotlib inline
import io
import h5py 
import pandas as pd
import scipy as sp
import numpy as np
from PIL import Image
from fractions import Fraction

from scipy import optimize 
from scipy.optimize import curve_fit,least_squares
from lmfit.models import GaussianModel
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colorbar import ColorbarBase, make_axes_gridspec
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
## Cube Neutron two inches from scintilator
## one inch 

# Thresholds minimums
energy_deposit_threshold = 0.1
energy_deposit_threshold_max =2
photon_threshold = 0
SiPM_hit_threshold = 0
LCE_threshold = 0
distance_threshold =  0 #inch

# Indexing for data sets

dfs = []

SiPM_n,widths = 1, 1
# Arrays
bins = 86                              # distance from SiPM
mins = np.zeros((SiPM_n,widths))          # minimum distance
maxs = np.zeros((SiPM_n,widths))          # maximum didtance
bes = np.zeros((SiPM_n,widths,bins+1))    # bin edges
bcs = np.zeros((SiPM_n,widths,bins))      # bin centers
averages = np.zeros((SiPM_n,widths,bins)) # average LCE per distances
fileName = 'cube_neutron/build-cubeneutron2/LXe_cube_nt_Neutron.csv'
df = []
nmp = []
pos = []
dist = []
for j in range(1):
    df.append(pd.read_csv(fileName, sep=',',header=None, skiprows=range(0,10),
                names=('Energy Deposited', 'SiPM Hits', 'Photons',
                        'x_pos','y_pos','z_pos')))
    df[j]['LCE']=df[j]['SiPM Hits']/df[j]['Photons']
    df[j]['log(LCE)']=log(df[j]['SiPM Hits']/df[j]['Photons'])
    nmp.append(df[j].to_numpy())
    pos.append(nmp[j][:,3:6])
    pos[j][:,2]=pos[j][:,2]-min(pos[j][:,2])
    pos[j]= pos[j]/25.4
    dist.append(sqrt(sum(pos[j]**2,axis=1)))
    df[j]['z_pos'] = pos[j][:,2].tolist()
    df[j]['y_pos'] = pos[j][:,1].tolist()
    df[j]['x_pos'] = pos[j][:,0].tolist()
    df[j]['Distance'] = dist[j].tolist()
dfs.append(df)

## Graphs
for i in range(1):  
    for j in range(1): 
        dfs[i][j] = dfs[i][j][dfs[i][j]['Energy Deposited']>=energy_deposit_threshold]
        dfs[i][j] = dfs[i][j][dfs[i][j]['Energy Deposited']<=energy_deposit_threshold_max]
        dfs[i][j] = dfs[i][j][dfs[i][j]['Photons']>=photon_threshold]
        dfs[i][j] = dfs[i][j][dfs[i][j]['LCE']>=LCE_threshold]
        dfs[i][j] = dfs[i][j][dfs[i][j]['SiPM Hits']>=SiPM_hit_threshold]
        dfs[i][j] = dfs[i][j][dfs[i][j]['Distance']>=distance_threshold] 
        mins[i,j]= np.min(dfs[i][j]['Distance'])
        maxs[i,j]= np.max(dfs[i][j]['Distance'])
        bes[i,j,:] = np.linspace(mins[i,j],maxs[i,j],bins+1)
        bcs[i,j,:] = bes[i,j,:-1] + np.diff(bes[i,j,:]) / 2.
        arraY = dfs[i][j]['Distance']
        for k in range(bins):
            msk = arraY>=bes[i,j,k]
            mask = arraY<bes[i,j,k+1]
            mk = msk == mask         
            averages[i,j,k] = dfs[i][j]['LCE'][mk].mean()

plt.figure(figsize=(16,10))
plt.title('Source Na22\nHistogram Energy deposited vs counts')
plt.xlabel('Energy (keVee)')
plt.ylabel('Counts')
plt.yscale('symlog')
counts, num = histogram(dfs[0][0]['Energy Deposited'],bins=bins)
plot(num[:-1],(counts),drawstyle='steps-mid')
show()          
            
plt.figure(figsize=(16,10))
plt.title('Energy thresholds {:.0f}-{:.0f} keV \nSource Na22\nHistogram SiPM hits counts vs SiPM hit number'.format(energy_deposit_threshold*1000,energy_deposit_threshold_max*1000))
plt.xlabel('SiPM Hits')
plt.ylabel('Counts')
plt.yscale('symlog')
counts, num = histogram(dfs[0][0]['SiPM Hits'],bins=bins)
plot(num[:-1],counts,drawstyle='steps-mid')
show()

# %%
## Cube Na22 two inches from scintilator
## one inch 

# Thresholds minimums
energy_deposit_threshold = 0.1
energy_deposit_threshold_max =2
photon_threshold = 0
SiPM_hit_threshold = 0
LCE_threshold = 0
distance_threshold =  0 #inch

# Indexing for data sets

dfs = []

SiPM_n,widths = 1, 1
# Arrays
bins = 86                              # distance from SiPM
mins = np.zeros((SiPM_n,widths))          # minimum distance
maxs = np.zeros((SiPM_n,widths))          # maximum didtance
bes = np.zeros((SiPM_n,widths,bins+1))    # bin edges
bcs = np.zeros((SiPM_n,widths,bins))      # bin centers
averages = np.zeros((SiPM_n,widths,bins)) # average LCE per distances
fileName = 'cube_Na22/build-cube_Na22/LXe_cube_nt_Na22.csv'
df = []
nmp = []
pos = []
dist = []
for j in range(1):
    df.append(pd.read_csv(fileName, sep=',',header=None, skiprows=range(0,10),
                names=('Energy Deposited', 'SiPM Hits', 'Photons',
                        'x_pos','y_pos','z_pos')))
    df[j]['LCE']=df[j]['SiPM Hits']/df[j]['Photons']
    df[j]['log(LCE)']=log(df[j]['SiPM Hits']/df[j]['Photons'])
    nmp.append(df[j].to_numpy())
    pos.append(nmp[j][:,3:6])
    pos[j][:,2]=pos[j][:,2]-min(pos[j][:,2])
    pos[j]= pos[j]/25.4
    dist.append(sqrt(sum(pos[j]**2,axis=1)))
    df[j]['z_pos'] = pos[j][:,2].tolist()
    df[j]['y_pos'] = pos[j][:,1].tolist()
    df[j]['x_pos'] = pos[j][:,0].tolist()
    df[j]['Distance'] = dist[j].tolist()
dfs.append(df)

## Graphs
for i in range(1):  
    for j in range(1): 
        dfs[i][j] = dfs[i][j][dfs[i][j]['Energy Deposited']>=energy_deposit_threshold]
        dfs[i][j] = dfs[i][j][dfs[i][j]['Energy Deposited']<=energy_deposit_threshold_max]
        dfs[i][j] = dfs[i][j][dfs[i][j]['Photons']>=photon_threshold]
        dfs[i][j] = dfs[i][j][dfs[i][j]['LCE']>=LCE_threshold]
        dfs[i][j] = dfs[i][j][dfs[i][j]['SiPM Hits']>=SiPM_hit_threshold]
        dfs[i][j] = dfs[i][j][dfs[i][j]['Distance']>=distance_threshold] 
        mins[i,j]= np.min(dfs[i][j]['Distance'])
        maxs[i,j]= np.max(dfs[i][j]['Distance'])
        bes[i,j,:] = np.linspace(mins[i,j],maxs[i,j],bins+1)
        bcs[i,j,:] = bes[i,j,:-1] + np.diff(bes[i,j,:]) / 2.
        arraY = dfs[i][j]['Distance']
        for k in range(bins):
            msk = arraY>=bes[i,j,k]
            mask = arraY<bes[i,j,k+1]
            mk = msk == mask         
            averages[i,j,k] = dfs[i][j]['LCE'][mk].mean()

plt.figure(figsize=(16,10))
plt.title('Source Na22\nHistogram Energy deposited vs counts')
plt.xlabel('Energy (keVee)')
plt.ylabel('Counts')
plt.yscale('symlog')
counts, num = histogram(dfs[0][0]['Energy Deposited'],bins=bins)
plot(num[:-1],(counts),drawstyle='steps-mid')
show()          
            
plt.figure(figsize=(16,10))
plt.title('Energy thresholds {:.0f}-{:.0f} keV \nSource Na22\nHistogram SiPM hits counts vs SiPM hit number'.format(energy_deposit_threshold*1000,energy_deposit_threshold_max*1000))
plt.xlabel('SiPM Hits')
plt.ylabel('Counts')
plt.yscale('symlog')
counts, num = histogram(dfs[0][0]['SiPM Hits'],bins=bins)
plot(num[:-1],counts,drawstyle='steps-mid')
show()

# %%
## Cylinder two inches from source
## one inch diameter and length

# Thresholds minimums
energy_deposit_threshold = 0.0
energy_deposit_threshold_max =2
photon_threshold = 0
SiPM_hit_threshold = 0
LCE_threshold = 0
distance_threshold =  0 #inch

# Indexing for data sets

dfs = []

SiPM_n,widths = 1, 1
# Arrays
bins = 84                              # distance from SiPM
mins = np.zeros((SiPM_n,widths))          # minimum distance
maxs = np.zeros((SiPM_n,widths))          # maximum didtance
bes = np.zeros((SiPM_n,widths,bins+1))    # bin edges
bcs = np.zeros((SiPM_n,widths,bins))      # bin centers
averages = np.zeros((SiPM_n,widths,bins)) # average LCE per distances


fileName = 'cylinder_Na22/build-cylinder_Na22/LXe_cylinder_nt_Na22.csv'
df = []
nmp = []
pos = []
dist = []
for j in range(1):


    df.append(pd.read_csv(fileName, sep=',',header=None, skiprows=range(0,10),
                names=('Energy Deposited', 'SiPM Hits', 'Photons',
                        'x_pos','y_pos','z_pos')))
    df[j]['LCE']=df[j]['SiPM Hits']/df[j]['Photons']
    df[j]['log(LCE)']=log(df[j]['SiPM Hits']/df[j]['Photons'])
    nmp.append(df[j].to_numpy())
    pos.append(nmp[j][:,3:6])
    pos[j][:,2]=pos[j][:,2]-min(pos[j][:,2])
    pos[j]= pos[j]/25.4
    dist.append(sqrt(sum(pos[j]**2,axis=1)))
    df[j]['z_pos'] = pos[j][:,2].tolist()
    df[j]['y_pos'] = pos[j][:,1].tolist()
    df[j]['x_pos'] = pos[j][:,0].tolist()
    df[j]['Distance'] = dist[j].tolist()
dfs.append(df)



## Graphs


for i in range(1):  
    for j in range(1): 
        dfs[i][j] = dfs[i][j][dfs[i][j]['Energy Deposited']>=energy_deposit_threshold]
        dfs[i][j] = dfs[i][j][dfs[i][j]['Energy Deposited']<=energy_deposit_threshold_max]
        dfs[i][j] = dfs[i][j][dfs[i][j]['Photons']>=photon_threshold]
        dfs[i][j] = dfs[i][j][dfs[i][j]['LCE']>=LCE_threshold]
        dfs[i][j] = dfs[i][j][dfs[i][j]['SiPM Hits']>=SiPM_hit_threshold]
        dfs[i][j] = dfs[i][j][dfs[i][j]['Distance']>=distance_threshold] 
        mins[i,j]= np.min(dfs[i][j]['Distance'])
        maxs[i,j]= np.max(dfs[i][j]['Distance'])
        bes[i,j,:] = np.linspace(mins[i,j],maxs[i,j],bins+1)
        bcs[i,j,:] = bes[i,j,:-1] + np.diff(bes[i,j,:]) / 2.
        arraY = dfs[i][j]['Distance']
        for k in range(bins):
            msk = arraY>=bes[i,j,k]
            mask = arraY<bes[i,j,k+1]
            mk = msk == mask         
            averages[i,j,k] = dfs[i][j]['LCE'][mk].mean()

plt.figure(figsize=(16,10))
plt.title('Energy thresholds {:.0f}-{:.0f} keV \nSource Na22\nHistogram Energy deposited vs counts'.format(energy_deposit_threshold*1000,energy_deposit_threshold_max*1000))
plt.xlabel('Energy (MeV)')
plt.ylabel('Counts')
plt.yscale('symlog')
counts, num = histogram(dfs[0][0]['Energy Deposited'],bins=bins)
plot(num[:-1],counts,drawstyle='steps-mid')


show()

plt.figure(figsize=(16,10))
plt.title('Energy thresholds {:.0f}-{:.0f} keV \nSource Na22\nHistogram SiPM hits counts vs SiPM hit number'.format(energy_deposit_threshold*1000,energy_deposit_threshold_max*1000))
plt.xlabel('SiPM Hits')
plt.ylabel('Counts')
plt.yscale('symlog')
counts, num = histogram(dfs[0][0]['SiPM Hits'],bins=bins)
plot(num[:-1],counts,drawstyle='steps-mid')


show()

# %%
dfs[0][0]
# Out:
#         Energy Deposited  SiPM Hits  Photons     x_pos     y_pos     z_pos  \
# 0               0.222433        486     1687  0.290972 -0.216110  0.090020
# 1               0.259800        529     1986 -0.309800 -0.207746  0.459167
# 2               0.114562        198      851  0.084204  0.327713  0.522657
# 3               0.030062         68      202 -0.289656  0.205489  0.538000
# 4               0.178864        352     1414  0.336208  0.312920  0.886688
# ...                  ...        ...      ...       ...       ...       ...
# 160508          0.088914        157      670 -0.134892 -0.152969  0.580273
# 160509          0.101305        203      756  0.318352  0.158438  0.172894
# 160510          0.106210        208      821 -0.276176  0.014535  0.349202
# 160511          0.098234        185      705 -0.465535 -0.076581  0.653178
# 160512          0.265199        544     2147 -0.076169 -0.286783  0.679778
#
#              LCE  log(LCE)  Distance
# 0       0.288085 -1.244498  0.373459
# 1       0.266365 -1.322889  0.591582
# 2       0.232667 -1.458145  0.622621
# 3       0.336634 -1.088760  0.644648
# 4       0.248939 -1.390547  0.998584
# ...          ...       ...       ...
# 160508  0.234328 -1.451032  0.615071
# 160509  0.268519 -1.314835  0.395402
# 160510  0.253350 -1.372985  0.445450
# 160511  0.262411 -1.337842  0.805747
# 160512  0.253377 -1.372878  0.741717
#
# [160513 rows x 9 columns]
